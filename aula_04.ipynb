# %%
#Importar pandas e seaborn
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"data\dataset_aula01_techshop_vendas.csv", parse_dates=["data_pedido"])

# %%
df.head()
# Out:
#   data_pedido    categoria  preco_unitario  quantidade    regiao  \
# 0  2024-01-01   Acessórios           36.20           1   Sudeste
# 1  2024-01-01   Acessórios          122.61           5   Sudeste
# 2  2024-01-02   Acessórios          151.19           4       Sul
# 3  2024-01-03          TVs         3399.16           2   Sudeste
# 4  2024-01-04  Smartphones         3180.94           2  Nordeste
#
#   canal_marketing  avaliacao
# 0       Instagram        3.3
# 1        Orgânico        4.4
# 2      Google Ads        4.6
# 3      Google Ads        4.1
# 4       Instagram        3.9

# %%
#Countplot é uma função para montar um gráfico.
grafico = sns.countplot(data=df,x="categoria");
grafico.set_title("Contagem por categoria");

#Funções para renomear as Legendas do eixo X e Y.
grafico.set_ylabel("Quantidade");
grafico.set_xlabel("Categorias");

# %%
#O histplot serve para gerar histogramas.
grafico = sns.histplot(data = df, x = "preco_unitario", kde = True, bins = 100);
grafico.set_title("Histograma");
grafico.set_ylabel("Quantidade de Vendas");
grafico.set_xlabel("Preços dos produtos");

# %%
#O boxplot será responsável por gerar gráficos em boxplot.
grafico = sns.boxplot(data = df, x = "categoria", y = "preco_unitario");
grafico.set_title("Distribuição de preços por Categoria");
grafico.set_xlabel("Categorias");
grafico.set_ylabel("Preços");
